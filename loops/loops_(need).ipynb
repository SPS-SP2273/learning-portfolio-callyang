# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 The for iterator

# %%
veggie = ["Potato","Celery","Beetroot"]

name = veggie[0]
print(f'{name} is good for you!')
      
name = veggie[1]
print(f'{name} is good for you!')

name = veggie[2]
print(f'{name} is good for you!')
# Out:
# Potato is good for you!
# Celery is good for you!
# Beetroot is good for you!

# %% [markdown]
# ## 1.1 for with a list

# %%
for name in veggie:
    print(f'{name} is good for you!')
# Out:
# Potato is good for you!
# Celery is good for you!
# Beetroot is good for you!

# %% [markdown]
# ## 1.2 for with enumerate

# %%
for i in veggie:
    print(i)
# Out:
# Potato
# Celery
# Beetroot

# %%
veggiearray = np.array(veggie)
for i,j in enumerate(veggiearray):
    print(i)
    print(j)
    
# enumerate works for array as well
# enumerate gives 2 output, the index of the elements in the store
# you enumerated, and the element inside the store itself
# Out:
# 0
# Potato
# 1
# Celery
# 2
# Beetroot

# %%
veggie = ["Potato","Celery","Beetroot"]
veggie_rating = ["yummy","nasty","ok"]

for count, vegname in enumerate(veggie):
    print(f'{count}: {vegname} is to be rated...')

for x, vegname in enumerate(veggie):
# ^ i , j in enumerate(list/array name)
# i will be the count from 0, and j will be name in elements
    rating = veggie_rating[x]
    print(f'{vegname} is {rating}, try it for yourself')
# for this ^ the count disappears because it is not given
# the print function
# run the below to get out the count
    print(f'{x}{vegname} is {rating}, try it for yourself')
    
# if uw count start from 100, do 
for x, y in enumerate(veggie,100):
    rating = veggie_rating[x-100]
    print(f'The {x}th veggie, {y} is rated {rating}!')
    # this does not work!!! because by putting veggie,100
    # the index (which is assigned to x in this case)
    # will start from 100
    # which cannot be put into veggie_rating[100]
    # cause it does not exist
# Out:
# 0: Potato is to be rated...
# 1: Celery is to be rated...
# 2: Beetroot is to be rated...
# Potato is yummy, try it for yourself
# 0Potato is yummy, try it for yourself
# Celery is nasty, try it for yourself
# 1Celery is nasty, try it for yourself
# Beetroot is ok, try it for yourself
# 2Beetroot is ok, try it for yourself
# The 100th veggie, Potato is rated yummy!
# The 101th veggie, Celery is rated nasty!
# The 102th veggie, Beetroot is rated ok!

# %% [markdown]
# ## 1.3 for with range

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
# adjust step size, like slicing except 
# dont have the 5-3 elements thing because in range what u put
# will be the numbers python runs

for i in range(1,10,3):
    print(i)
# Out:
# 1
# 4
# 7

# %%
super_names = ["Black Widow", "Iron Man", "Doctor Strange"]
real_names = ["Natasha Romanoff", "Tony Stark", "Stephen Strange"]

for i in range(len(real_names)):
    real_name = real_names[i]
    super_name = super_names[i]
    print(f"{real_name} is Marvel's {super_name}")
# Out:
# Natasha Romanoff is Marvel's Black Widow
# Tony Stark is Marvel's Iron Man
# Stephen Strange is Marvel's Doctor Strange
# Natasha Romanoff is Marvel's Black Widow
# Tony Stark is Marvel's Iron Man
# Stephen Strange is Marvel's Doctor Strange

# %% [markdown]
# # 2 while

# %%
number = 0
while number < 5:
    print(number)
    number += 1
# Out:
# 0
# 1
# 2
# 3
# 4
