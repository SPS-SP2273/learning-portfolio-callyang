# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Need) Exercises</span></div>

# %% [markdown]
# Exercise 1

# %%
def greeting(name):
    if name == 'Batman':
        return 'Hello Batman! So, nice to meet you!'
    return f'Hello {name}!'

# %% [markdown]
# The above code works though it does not have an else statement, because only if name is Batman as indicated by the if statement, the function will return 'Hello Batman! So, nice to meet you!'. There is already kind of an otherwise, if name is NOT Batman, it will skip the next line of code and go on to return the last line 'Hello {name}!' because the indentation of the last statement is outside the if condition.

# %% [markdown]
# Exercise 2

# %%
def calculate_bmi(weight, height):
    BMI = f'{weight/(height**2):.1f}' # set to 1dp
    BMI = float(BMI)
    
    if(BMI<18.5):
        category = "Underweight"
    if(18.5<=BMI<=24.9):
        category = "Normal weight"
    if(25<=BMI<=29.9):
        category = "Overweight"
    if(BMI>=30):
        category = "Obesity"
        
    print(f'Your category is {category}')

# %%
calculate_bmi(90,1.9) # does not work because BMI is 24.93 which is 
                      # between 24.9 and 25 in value
                      # unless rounded to 1dp
                      # float otherwise if u use int() it will not convert
# Out:
# Your category is Normal weight
