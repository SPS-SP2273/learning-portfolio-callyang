# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Good) Exercises</span></div>

# %% [markdown]
# Exercise 1

# %%
for number in range(10):
    if number%2 == 0:
        continue
    else:
        oddintsq = number**2
    print(oddintsq)
# Out:
# 1
# 9
# 25
# 49
# 81

# %% [markdown]
# Exercise 2

# %%
[number**2 for number in range(10) if number%2 !=0]
# Out:
# [1, 9, 25, 49, 81]

# %% [markdown]
# Exercise 3

# %%
list(range(2, 9))
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
list(range(2,8))[1]
# Out:
# 3

# %%
# %timeit [number**2 for number in range(10) if number%2 !=0]
# Out:
# 745 ns ± 3.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit

for number in range(10):
    if number%2 == 0:
        continue
    else:
        oddintsq = number**2
    #print(oddintsq) # this keeps going many times because timeit
                    # repeats the whole code
                    # so to fix, don't include print statement
# Out:
# 590 ns ± 0.598 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# The way without list comprehension is faster.

# %% [markdown]
# Exercise 4

# %%
radsub = 100
count = 0
while(radsub>50):
    count += 1
    radsub = radsub*0.95
print(count)

# 14 years
# Out:
# 14

# %% [markdown]
# Exercise 5

# %%
co2_data = [
    (2000, 369.55), (2001, 371.14), (2002, 373.28), 
    (2003, 375.80), (2004, 377.52), (2005, 379.80), 
    (2006, 381.90), (2007, 383.79), (2008, 385.60), 
    (2009, 387.43), (2010, 389.90), (2011, 391.65), 
    (2012, 393.85), (2013, 396.52), (2014, 398.65),
    (2015, 400.83), (2016, 404.24), (2017, 406.55), 
    (2018, 408.52), (2019, 411.44), (2020, 414.24)
]

co2array = np.array(co2_data)

temparray = co2array[0:,1]

for i in range(21):
    if(temparray[i]-temparray[i-1]>3):
        print(temparray[i]-temparray[i-1])
        print(co2array[i,0])
        
# in 2016, there was an increase in CO2 concentration of 3.41ppm
# Out:
# 3.410000000000025
# 2016.0
