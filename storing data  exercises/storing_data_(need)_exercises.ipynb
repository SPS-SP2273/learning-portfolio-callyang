# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Storing Data (Need) Exercises</span></div>

# %% [markdown]
# Exercise 1
# - Two similarities between lists and arrays are:
# 1. Both can be multiplied, but results are different- list increase in length while elements inside arrays are multiplied
# 2. *Can access data using [] for both arrays and list*
#
# - Two differences between lists and arrays are:
# 1. Addition works on arrays to add to each element, but does not work for lists
# 2. List is already inbuilt in Python, but to make array need to import numpy as np and use np.array([]) or np.array(name of the list)
#
# - A dictionary is a form of data storage in a key-value format, where each value is assigned to a key and can be called out by []

# %% [markdown]
# Exercise 2

# %%
py_list = ["a1", "b2", "c3", "d4", "e5", "f6", "g7", "h8", "i9", "j10"]

print(py_list[0]) # prints 'a1'
print(py_list[2]) # prints 'c3'
print(py_list[4]) # prints 'e5'
print(py_list[6]) # prints 'g7'
print(py_list[8]) # prints 'i9'
# Out:
# a1
# c3
# e5
# g7
# i9

# %% [markdown]
# Exercise 3

# %%
elements = ['Hydrogen',
            'Helium', 'Lithium',
            'Beryllium', 'Boron', 'Carbon',
            'Nitrogen', 'Oxygen',
            'Fluorine',
            'Neon']

# %%
print(elements[4])
print(elements[-4])
# Out:
# Boron
# Nitrogen

# %%
numbers=[45, 60, 1, 30, 96, 1, 96, 57, 16, 1,
        99, 62, 86, 43, 42, 60, 59, 1, 1, 35,
        83, 47, 34, 28, 68, 23, 22, 92, 1, 79,
        1, 29, 94, 72, 46, 47, 1, 74, 32, 20,
        8, 37, 35, 1, 89, 29, 86, 19, 43, 61]      

sumofones = numbers.count(1)  # .count() for list, put what you
print(sumofones)              # want the number of (in this case, 1)
                              # in the brackets
# Out:
# 9

# %%
numbers=[45, 60, 1, 30, 96, 1, 96, 57, 16, 1,
        99, 62, 86, 43, 42, 60, 59, 1, 1, 35,
        83, 47, 34, 28, 68, 23, 22, 92, 1, 79,
        1, 29, 94, 72, 46, 47, 1, 74, 32, 20,
        8, 37, 35, 1, 89, 29, 86, 19, 43, 61]      

numbersarray = np.array(numbers)

sumofones = sum(numbersarray == True) 

# numbersarray == True gives an array of True False True False
# as python checks whether each element is True,, 
# or 1,, since True is same as 1
# then, we re able to take the sum of this new array:
# using sum(numberarays == True)
# and since it is stored as True False True False
# it also is stored as 1 0 1 0 0 1 etc
# hence array is able to give us a sum

print(f'The number of 1\'s in the list is {sumofones}')
# Out:
# The number of 1's in the list is 9
