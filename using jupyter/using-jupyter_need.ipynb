# %%
print ('hello world')
# Out:
# hello world

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don't

# %%
he ships *hung up the sky* up much the same way that **bricks don't.**<sup>1</sup><sub>QUOTE</sub>
# Out:
#   Cell In[4], line 1
#     he ships *hung up the sky* up much the same way that **bricks don't.**<sup>1</sup><sub>QUOTE</sub>
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
The ships *hung up the sky* much the same way that **bricks dont.**<sup>1</sup><sub>QUOTE</sub>
# Out:
#   Cell In[5], line 1
#     The ships *hung up the sky* much the same way that **bricks dont.**<sup>1</sup><sub>QUOTE</sub>
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# 'print('hello world')'

# %%
```python
print('Hello World!')
```
# Out:
#   Cell In[6], line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %%
![](https://nus.edu.sg/images/default-source/base/logo.png)
# Out:
# zsh:1: unknown file attribute: h

# %%
!(https://nus.edu.sg/images/default-source/base/logo.png)
# Out:
# zsh:1: no such file or directory: https://nus.edu.sg/images/default-source/base/logo.png

# %%
![](https://nus.edu.sg/images/default-source/base/logo.png)
# Out:
# zsh:1: unknown file attribute: h

# %% [markdown]
# | A    |  B   |    C |
# | :--- | :--: | ---: |
# | a1   |  b1  |   c1 |
# | a2   |  b2  |   c2 |
# | a3   |  b3  |   c3 |

# %%
| X
# Out:
#   Cell In[10], line 1
#     | X
#     ^
# SyntaxError: invalid syntax

# %%
| X   |  Y   |  Z  |
| :---| :--: | ---:|
|1    |2     | 2   |
# Out:
#   Cell In[11], line 1
#     | X   |  Y   |  Z  |
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# $/alpha$
